# %%
# %run phugoid.py
# Out:
# ERROR: File `'phugoid.py'` not found.

# %%
pwd
# Out:
# '/home/NDodbele/numerical-mooc/NikitaDodbele'

# %%
# %run ..
# Out:
# ERROR: File `'...py'` not found.

# %%
# %run ../lessons/01_phugoid/phugoid.py

# %%
# %matplotlib inline

# %%
plot_flight_path(32, 16, 0)
